# %% [markdown]
# Technical Analysis of the relationship between NIKKEI225, NIFTY50 and S&P500

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
#Nikkei 225
nik = yf.download(tickers='^N225', period='1y', interval='1d')
#S&P 500
snp = yf.download(tickers='^GSPC', period='1y', interval='1d')
#NIFTY 50 
nif = yf.download(tickers='^NSEI', period='1y', interval='1d')

#nik.head(5)
#snp.head(5)
#nif.head(5)
display(nik.head(5),snp.head(5),nif.head(5))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2022-07-14  26357.320312  26713.070312  26312.789062  26643.390625
# 2022-07-15  26736.080078  26857.769531  26571.380859  26788.470703
# 2022-07-19  27003.830078  27043.580078  26791.710938  26961.679688
# 2022-07-20  27295.949219  27692.849609  27295.949219  27680.259766
# 2022-07-21  27627.880859  27803.000000  27549.560547  27803.000000
#
#                Adj Close    Volume
# Date
# 2022-07-14  26643.390625  60600000
# 2022-07-15  26788.470703  65500000
# 2022-07-19  26961.679688  59400000
# 2022-07-20  27680.259766  66700000
# 2022-07-21  27803.000000  56700000
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-07-15  3818.000000  3863.620117  3817.179932  3863.159912  3863.159912
# 2022-07-18  3883.790039  3902.439941  3818.629883  3830.850098  3830.850098
# 2022-07-19  3860.729980  3939.810059  3860.729980  3936.689941  3936.689941
# 2022-07-20  3935.320068  3974.129883  3922.030029  3959.899902  3959.899902
# 2022-07-21  3955.469971  3999.290039  3927.639893  3998.949951  3998.949951
#
#                 Volume
# Date
# 2022-07-15  4143800000
# 2022-07-18  4046870000
# 2022-07-19  4041070000
# 2022-07-20  4185300000
# 2022-07-21  4132790000
#                     Open          High           Low         Close  \
# Date
# 2022-07-14  16018.849609  16070.849609  15858.200195  15938.650391
# 2022-07-15  16010.799805  16066.950195  15927.299805  16049.200195
# 2022-07-18  16151.400391  16287.950195  16142.200195  16278.500000
# 2022-07-19  16187.049805  16359.500000  16187.049805  16340.549805
# 2022-07-20  16562.800781  16588.000000  16490.949219  16520.849609
#
#                Adj Close  Volume
# Date
# 2022-07-14  15938.650391  228600
# 2022-07-15  16049.200195  205800
# 2022-07-18  16278.500000  227700
# 2022-07-19  16340.549805  222600
# 2022-07-20  16520.849609  284400

# %% [markdown]
# "Open": This column shows the opening price of the stock at the beginning of each time interval.
#
# "High": This column indicates the highest price reached by the stock during each time interval.
#
# "Low": This column represents the lowest price reached by the stock during each time interval.
#
# "Close": This column shows the closing price of the stock at the end of each time interval.
#
# "Adj Close": This column represents the adjusted closing price of the stock, which takes into account any corporate actions or events affecting the stock's price.
#
# "Volume": This column indicates the trading volume, i.e., the total number of shares or contracts traded during each time interval.

# %%
tickers = ['^NSEI', '^GSPC', '^N225']  # Updated ticker symbols for Sensex, S&P 500, and Nikkei
adj1 = yf.download(tickers, start='2008-07-01', end='2009-07-01')['Adj Close']

# Calculate percentage growth
percentage_growth = adj1.pct_change() * 100

plt.figure(figsize=(50, 12))
for ticker in tickers:
    plt.plot(percentage_growth.index, percentage_growth[ticker], label=ticker)

plt.title('Percentage Growth Comparison')
plt.xlabel('Date')
plt.ylabel('Percentage Growth')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
#tickers = ['^GSPC']
#vol1 = yf.download(tickers, start='2008-07-01', end='2009-07-01')['Volume']
vol1 = yf.download("^GSPC", start='2008-07-01', end='2009-07-01')['Volume']
plt.figure(figsize=(50, 12))
#for ticker in tickers:
#    plt.plot(vol1.index, vol1[ticker], label=ticker)
plt.plot(vol1.index, vol1, label="^GSPC")
plt.title('Volumne Comparison')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.show()
vol1
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2008-07-01    5846290000
# 2008-07-02    5276090000
# 2008-07-03    3247590000
# 2008-07-07    5265420000
# 2008-07-08    6034110000
#                  ...
# 2009-06-24    4636720000
# 2009-06-25    4911240000
# 2009-06-26    6076660000
# 2009-06-29    4211760000
# 2009-06-30    4627570000
# Name: Volume, Length: 252, dtype: int64

# %%
# Nikkei 225
nik = yf.download(tickers='^N225', start='2008-07-01', end='2009-07-01', interval='1d')

# S&P 500
snp = yf.download(tickers='^GSPC', start='2008-07-01', end='2009-07-01', interval='1d')

# NIFTY 50
bse = yf.download(tickers='^BSESN', start='2008-07-01', end='2009-07-01', interval='1d')

#nik_pg = nik.pct_change() * 100
#snp_pg = snp.pct_change() * 100
#bse_pg = bse.pct_change() * 100
#nik_v= nik/(10^8)
#snp_v= snp/(10^10)
#bse_v=bse/(10^6)

#plt.figure(figsize=(50, 12))
#plt.plot(percentage_growth.index, percentage_growth[ticker], label=ticker)

#nik_v["Volume"].plot(label="NIKKEI",figsize=(15,7))
nik["Volume"].plot(label="NIKKEI",figsize=(15,7))
snp["Volume"].plot(label="S&P")
bse["Volume"].plot(label="BSESN")
plt.ylabel("Volume")
plt.legend()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
